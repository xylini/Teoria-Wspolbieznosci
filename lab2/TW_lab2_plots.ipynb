# %%
using DataFrames
using Plots
using CSV
using StatPlots
using Statistics

# %%
#Consumer the same M
ddpi = (800, 700)
#normal - normal 
ready_consumerPK10M1000 = by(sort(CSV.read("consumerPK10M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot(ready_consumerPK10M1000[3],
     ready_consumerPK10M1000[4],
     title = "M = 1000",
     label = "norm PK 10",
     size = ddpi,
      w = 2)

ready_consumerPK100M1000 = by(sort(CSV.read("consumerPK100M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_consumerPK100M1000[3],
      ready_consumerPK100M1000[4],
      title = "M = 1000",
      label = "norm PK 100",
      size = ddpi,
      w = 2)

ready_consumerPK1000M1000 = by(sort(CSV.read("consumerPK1000M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_consumerPK1000M1000[3],
      ready_consumerPK1000M1000[4],
      title = "M = 1000",
      label = "norm PK 1000",
      size = ddpi,
      w = 2)


#normal - small value more possible
ready_SVconsumerPK10M1000 = by(sort(CSV.read("SVconsumerPK10M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVconsumerPK10M1000[3],
      ready_SVconsumerPK10M1000[4],
      title = "M = 1000",
      label = "norm SV PK 10",
      size = ddpi,
      w = 2)

ready_SVconsumerPK100M1000 = by(sort(CSV.read("SVconsumerPK100M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVconsumerPK100M1000[3],
      ready_SVconsumerPK100M1000[4],
      title = "M = 1000",
      label = "norm SV PK 100",
      size = ddpi,
      w = 2)

ready_SVconsumerPK1000M1000 = by(sort(CSV.read("SVconsumerPK1000M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVconsumerPK1000M1000[3],
      ready_SVconsumerPK1000M1000[4],
      title = "M = 1000",
      label = "norm SV PK 1000",
      size = ddpi,
      w = 2)

#fair - normal 
ready_fairConsumerPK10M1000 = by(sort(CSV.read("fairConsumerPK10M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairConsumerPK10M1000[3],
      ready_fairConsumerPK10M1000[4],
      title = "M = 1000",
      label = "fair PK 10",
      size = ddpi,
      w = 2)

ready_fairConsumerPK100M1000 = by(sort(CSV.read("fairConsumerPK100M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairConsumerPK100M1000[3],
      ready_fairConsumerPK100M1000[4],
      title = "M = 1000",
      label = "fair PK 100",
      size = ddpi,
      w = 2)

ready_fairConsumerPK1000M1000 = by(sort(CSV.read("fairConsumerPK1000M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairConsumerPK1000M1000[3],
      ready_fairConsumerPK1000M1000[4],
      title = "M = 1000",
      label = "fair PK 1000",
      size = ddpi,
      w = 2)

#fair - small value more possible
ready_fairSVConsumerPK10M1000 = by(sort(CSV.read("fairSVConsumerPK10M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVConsumerPK10M1000[3],
      ready_fairSVConsumerPK10M1000[4],
      title = "M = 1000",
      label = "fair SV PK 10",
      size = ddpi,
      w = 2)

ready_fairSVConsumerPK100M1000 = by(sort(CSV.read("fairSVConsumerPK100M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVConsumerPK100M1000[3],
      ready_fairSVConsumerPK100M1000[4],
      title = "M = 1000",
      label = "fair SV PK 100",
      size = ddpi,
      w = 2)

ready_fairSVConsumerPK1000M1000 = by(sort(CSV.read("fairSVConsumerPK1000M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

consumerM1000 = plot!(ready_fairSVConsumerPK1000M1000[3],
      ready_fairSVConsumerPK1000M1000[4],
      title = "Consumer - M = 1000",
      label = "fair SV PK 1000",
      size = ddpi,
      ylabel = "Time [ns]",
      xlabel = "Buffer size",
      legend = :topleft,
      w = 2)
print()

# %%
#Producer the same M
ddpi = (800, 700)
#normal - normal 
ready_producerPK10M1000 = by(sort(CSV.read("producerPK10M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot(ready_producerPK10M1000[3],
     ready_producerPK10M1000[4],
     title = "M = 1000",
     label = "norm PK 10",
     size = ddpi,
      w = 2)

ready_producerPK100M1000 = by(sort(CSV.read("producerPK100M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_producerPK100M1000[3],
      ready_producerPK100M1000[4],
      title = "M = 1000",
      label = "norm PK 100",
      size = ddpi,
      w = 2)

ready_producerPK1000M1000 = by(sort(CSV.read("producerPK1000M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_producerPK1000M1000[3],
      ready_producerPK1000M1000[4],
      title = "M = 1000",
      label = "norm PK 1000",
      size = ddpi,
      w = 2)


#normal - small value more possible
ready_SVproducerPK10M1000 = by(sort(CSV.read("SVproducerPK10M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVproducerPK10M1000[3],
      ready_SVproducerPK10M1000[4],
      title = "M = 1000",
      label = "norm SV PK 10",
      size = ddpi,
      w = 2)

ready_SVproducerPK100M1000 = by(sort(CSV.read("SVproducerPK100M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVproducerPK100M1000[3],
      ready_SVproducerPK100M1000[4],
      title = "M = 1000",
      label = "norm SV PK 100",
      size = ddpi,
      w = 2)

ready_SVproducerPK1000M1000 = by(sort(CSV.read("SVproducerPK1000M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVproducerPK1000M1000[3],
      ready_SVproducerPK1000M1000[4],
      title = "M = 1000",
      label = "norm SV PK 1000",
      size = ddpi,
      w = 2)

#fair - normal 
ready_fairProducerPK10M1000 = by(sort(CSV.read("fairProducerPK10M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairProducerPK10M1000[3],
      ready_fairProducerPK10M1000[4],
      title = "M = 1000",
      label = "fair PK 10",
      size = ddpi,
      w = 2)

ready_fairProducerPK100M1000 = by(sort(CSV.read("fairProducerPK100M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairProducerPK100M1000[3],
      ready_fairProducerPK100M1000[4],
      title = "M = 1000",
      label = "fair PK 100",
      size = ddpi,
      w = 2)

ready_fairProducerPK1000M1000 = by(sort(CSV.read("fairProducerPK1000M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairProducerPK1000M1000[3],
      ready_fairProducerPK1000M1000[4],
      title = "M = 1000",
      label = "fair PK 1000",
      size = ddpi,
      w = 2)

#fair - small value more possible
ready_fairSVProducerPK10M1000 = by(sort(CSV.read("fairSVProducerPK10M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVProducerPK10M1000[3],
      ready_fairSVProducerPK10M1000[4],
      title = "M = 1000",
      label = "fair SV PK 10",
      size = ddpi,
      w = 2)

ready_fairSVProducerPK100M1000 = by(sort(CSV.read("fairSVProducerPK100M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVProducerPK100M1000[3],
      ready_fairSVProducerPK100M1000[4],
      title = "M = 1000",
      label = "fair SV PK 100",
      size = ddpi,
      w = 2)

ready_fairSVProducerPK1000M1000 = by(sort(CSV.read("fairSVProducerPK1000M1000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

producerM1000 = plot!(ready_fairSVProducerPK1000M1000[3],
      ready_fairSVProducerPK1000M1000[4],
      title = "Producer - M = 1000",
      label = "fair SV PK 1000",
      size = ddpi,
      ylabel = "Time [ns]",
      xlabel = "Buffer size",
      legend = :topleft,
      w = 2)

print()

# %%
#Consumer the same M
ddpi = (800, 700)
#normal - normal 
ready_consumerPK10M10000 = by(sort(CSV.read("consumerPK10M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot(ready_consumerPK10M10000[3],
     ready_consumerPK10M10000[4],
     title = "M = 10000",
     label = "norm PK 10",
     size = ddpi,
      w = 2)

ready_consumerPK100M10000 = by(sort(CSV.read("consumerPK100M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_consumerPK100M10000[3],
      ready_consumerPK100M10000[4],
      title = "M = 10000",
      label = "norm PK 100",
      size = ddpi,
      w = 2)

ready_consumerPK1000M10000 = by(sort(CSV.read("consumerPK1000M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_consumerPK1000M10000[3],
      ready_consumerPK1000M10000[4],
      title = "M = 10000",
      label = "norm PK 1000",
      size = ddpi,
      w = 2)


#normal - small value more possible
ready_SVconsumerPK10M10000 = by(sort(CSV.read("SVconsumerPK10M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVconsumerPK10M10000[3],
      ready_SVconsumerPK10M10000[4],
      title = "M = 10000",
      label = "norm SV PK 10",
      size = ddpi,
      w = 2)

ready_SVconsumerPK100M10000 = by(sort(CSV.read("SVconsumerPK100M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVconsumerPK100M10000[3],
      ready_SVconsumerPK100M10000[4],
      title = "M = 10000",
      label = "norm SV PK 100",
      size = ddpi,
      w = 2)

ready_SVconsumerPK1000M10000 = by(sort(CSV.read("SVconsumerPK1000M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVconsumerPK1000M10000[3],
      ready_SVconsumerPK1000M10000[4],
      title = "M = 10000",
      label = "norm SV PK 1000",
      size = ddpi,
      w = 2)

#fair - normal 
ready_fairConsumerPK10M10000 = by(sort(CSV.read("fairConsumerPK10M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairConsumerPK10M10000[3],
      ready_fairConsumerPK10M10000[4],
      title = "M = 10000",
      label = "fair PK 10",
      size = ddpi,
      w = 2)

ready_fairConsumerPK100M10000 = by(sort(CSV.read("fairConsumerPK100M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairConsumerPK100M10000[3],
      ready_fairConsumerPK100M10000[4],
      title = "M = 10000",
      label = "fair PK 100",
      size = ddpi,
      w = 2)

ready_fairConsumerPK1000M10000 = by(sort(CSV.read("fairConsumerPK1000M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairConsumerPK1000M10000[3],
      ready_fairConsumerPK1000M10000[4],
      title = "M = 10000",
      label = "fair PK 1000",
      size = ddpi,
      w = 2)

#fair - small value more possible
ready_fairSVConsumerPK10M10000 = by(sort(CSV.read("fairSVConsumerPK10M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVConsumerPK10M10000[3],
      ready_fairSVConsumerPK10M10000[4],
      title = "M = 10000",
      label = "fair SV PK 10",
      size = ddpi,
      w = 2)

ready_fairSVConsumerPK100M10000 = by(sort(CSV.read("fairSVConsumerPK100M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVConsumerPK100M10000[3],
      ready_fairSVConsumerPK100M10000[4],
      title = "M = 10000",
      label = "fair SV PK 100",
      size = ddpi,
      w = 2)

ready_fairSVConsumerPK1000M10000 = by(sort(CSV.read("fairSVConsumerPK1000M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

consumerM10000 = plot!(ready_fairSVConsumerPK1000M10000[3],
      ready_fairSVConsumerPK1000M10000[4],
      title = "Consumer - M = 10000",
      label = "fair SV PK 1000",
      size = ddpi,
      ylabel = "Time [ns]",
      xlabel = "Buffer size",
      legend = :topleft,
      w = 2)

print()

# %%
#Producer the same M
ddpi = (800, 700)
#normal - normal 
ready_producerPK10M10000 = by(sort(CSV.read("producerPK10M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot(ready_producerPK10M10000[3],
     ready_producerPK10M10000[4],
     title = "M = 10000",
     label = "norm PK 10",
     size = ddpi,
      w = 2)

ready_producerPK100M10000 = by(sort(CSV.read("producerPK100M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_producerPK100M10000[3],
      ready_producerPK100M10000[4],
      title = "M = 10000",
      label = "norm PK 100",
      size = ddpi,
      w = 2)

ready_producerPK1000M10000 = by(sort(CSV.read("producerPK1000M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_producerPK1000M10000[3],
      ready_producerPK1000M10000[4],
      title = "M = 10000",
      label = "norm PK 1000",
      size = ddpi,
      w = 2)


#normal - small value more possible
ready_SVproducerPK10M10000 = by(sort(CSV.read("SVproducerPK10M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVproducerPK10M10000[3],
      ready_SVproducerPK10M10000[4],
      title = "M = 10000",
      label = "norm SV PK 10",
      size = ddpi,
      w = 2)

ready_SVproducerPK100M10000 = by(sort(CSV.read("SVproducerPK100M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVproducerPK100M10000[3],
      ready_SVproducerPK100M10000[4],
      title = "M = 10000",
      label = "norm SV PK 100",
      size = ddpi,
      w = 2)

ready_SVproducerPK1000M10000 = by(sort(CSV.read("SVproducerPK1000M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVproducerPK1000M10000[3],
      ready_SVproducerPK1000M10000[4],
      title = "M = 10000",
      label = "norm SV PK 1000",
      size = ddpi,
      w = 2)

#fair - normal 
ready_fairProducerPK10M10000 = by(sort(CSV.read("fairProducerPK10M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairProducerPK10M10000[3],
      ready_fairProducerPK10M10000[4],
      title = "M = 10000",
      label = "fair PK 10",
      size = ddpi,
      w = 2)

ready_fairProducerPK100M10000 = by(sort(CSV.read("fairProducerPK100M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairProducerPK100M10000[3],
      ready_fairProducerPK100M10000[4],
      title = "M = 10000",
      label = "fair PK 100",
      size = ddpi,
      w = 2)

ready_fairProducerPK1000M10000 = by(sort(CSV.read("fairProducerPK1000M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairProducerPK1000M10000[3],
      ready_fairProducerPK1000M10000[4],
      title = "M = 10000",
      label = "fair PK 1000",
      size = ddpi,
      w = 2)

#fair - small value more possible
ready_fairSVProducerPK10M10000 = by(sort(CSV.read("fairSVProducerPK10M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVProducerPK10M10000[3],
      ready_fairSVProducerPK10M10000[4],
      title = "M = 10000",
      label = "fair SV PK 10",
      size = ddpi,
      w = 2)

ready_fairSVProducerPK100M10000 = by(sort(CSV.read("fairSVProducerPK100M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVProducerPK100M10000[3],
      ready_fairSVProducerPK100M10000[4],
      title = "M = 10000",
      label = "fair SV PK 100",
      size = ddpi,
      w = 2)

ready_fairSVProducerPK1000M10000 = by(sort(CSV.read("fairSVProducerPK1000M10000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

producerM10000 = plot!(ready_fairSVProducerPK1000M10000[3],
      ready_fairSVProducerPK1000M10000[4],
      title = "Producer - M = 10000",
      label = "fair SV PK 1000",
      size = ddpi,
      ylabel = "Time [ns]",
      xlabel = "Buffer size",
      legend = :topleft,
      w = 2)

print()

# %%
#Consumer the same M
ddpi = (800, 700)
#normal - normal 
ready_consumerPK10M100000 = by(sort(CSV.read("consumerPK10M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot(ready_consumerPK10M100000[3],
     ready_consumerPK10M100000[4],
     title = "M = 100000",
     label = "norm PK 10",
     size = ddpi,
      w = 2)

ready_consumerPK100M100000 = by(sort(CSV.read("consumerPK100M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_consumerPK100M100000[3],
      ready_consumerPK100M100000[4],
      title = "M = 100000",
      label = "norm PK 100",
      size = ddpi,
      w = 2)

ready_consumerPK1000M100000 = by(sort(CSV.read("consumerPK1000M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_consumerPK1000M100000[3],
      ready_consumerPK1000M100000[4],
      title = "M = 100000",
      label = "norm PK 1000",
      size = ddpi,
      w = 2)


#normal - small value more possible
ready_SVconsumerPK10M100000 = by(sort(CSV.read("SVconsumerPK10M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVconsumerPK10M100000[3],
      ready_SVconsumerPK10M100000[4],
      title = "M = 100000",
      label = "norm SV PK 10",
      size = ddpi,
      w = 2)

ready_SVconsumerPK100M100000 = by(sort(CSV.read("SVconsumerPK100M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVconsumerPK100M100000[3],
      ready_SVconsumerPK100M100000[4],
      title = "M = 100000",
      label = "norm SV PK 100",
      size = ddpi,
      w = 2)

ready_SVconsumerPK1000M100000 = by(sort(CSV.read("SVconsumerPK1000M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVconsumerPK1000M100000[3],
      ready_SVconsumerPK1000M100000[4],
      title = "M = 100000",
      label = "norm SV PK 1000",
      size = ddpi,
      w = 2)

#fair - normal 
ready_fairConsumerPK10M100000 = by(sort(CSV.read("fairConsumerPK10M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairConsumerPK10M100000[3],
      ready_fairConsumerPK10M100000[4],
      title = "M = 100000",
      label = "fair PK 10",
      size = ddpi,
      w = 2)

ready_fairConsumerPK100M100000 = by(sort(CSV.read("fairConsumerPK100M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairConsumerPK100M100000[3],
      ready_fairConsumerPK100M100000[4],
      title = "M = 100000",
      label = "fair PK 100",
      size = ddpi,
      w = 2)

ready_fairConsumerPK1000M100000 = by(sort(CSV.read("fairConsumerPK1000M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairConsumerPK1000M100000[3],
      ready_fairConsumerPK1000M100000[4],
      title = "M = 100000",
      label = "fair PK 1000",
      size = ddpi,
      w = 2)

#fair - small value more possible
ready_fairSVConsumerPK10M100000 = by(sort(CSV.read("fairSVConsumerPK10M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVConsumerPK10M100000[3],
      ready_fairSVConsumerPK10M100000[4],
      title = "M = 100000",
      label = "fair SV PK 10",
      size = ddpi,
      w = 2)

ready_fairSVConsumerPK100M100000 = by(sort(CSV.read("fairSVConsumerPK100M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVConsumerPK100M100000[3],
      ready_fairSVConsumerPK100M100000[4],
      title = "M = 100000",
      label = "fair SV PK 100",
      size = ddpi,
      w = 2)

ready_fairSVConsumerPK1000M100000 = by(sort(CSV.read("fairSVConsumerPK1000M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

consumerM100000 = plot!(ready_fairSVConsumerPK1000M100000[3],
      ready_fairSVConsumerPK1000M100000[4],
      title = "Consumer - M = 100000",
      label = "fair SV PK 1000",
      size = ddpi,
      ylabel = "Time [ns]",
      xlabel = "Buffer size",
      legend = :topleft,
      w = 2)

print()

# %%
#Producer the same M
ddpi = (800, 700)
#normal - normal 
ready_producerPK10M100000 = by(sort(CSV.read("producerPK10M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot(ready_producerPK10M100000[3],
     ready_producerPK10M100000[4],
     title = "M = 100000",
     label = "norm PK 10",
     size = ddpi,
      w = 2)

ready_producerPK100M100000 = by(sort(CSV.read("producerPK100M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_producerPK100M100000[3],
      ready_producerPK100M100000[4],
      title = "M = 100000",
      label = "norm PK 100",
      size = ddpi,
      w = 2)

ready_producerPK1000M100000 = by(sort(CSV.read("producerPK1000M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_producerPK1000M100000[3],
      ready_producerPK1000M100000[4],
      title = "M = 100000",
      label = "norm PK 1000",
      size = ddpi,
      w = 2)


#normal - small value more possible
ready_SVproducerPK10M100000 = by(sort(CSV.read("SVproducerPK10M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVproducerPK10M100000[3],
      ready_SVproducerPK10M100000[4],
      title = "M = 100000",
      label = "norm SV PK 10",
      size = ddpi,
      w = 2)

ready_SVproducerPK100M100000 = by(sort(CSV.read("SVproducerPK100M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVproducerPK100M100000[3],
      ready_SVproducerPK100M100000[4],
      title = "M = 100000",
      label = "norm SV PK 100",
      size = ddpi,
      w = 2)

ready_SVproducerPK1000M100000 = by(sort(CSV.read("SVproducerPK1000M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_SVproducerPK1000M100000[3],
      ready_SVproducerPK1000M100000[4],
      title = "M = 100000",
      label = "norm SV PK 1000",
      size = ddpi,
      w = 2)

#fair - normal 
ready_fairProducerPK10M100000 = by(sort(CSV.read("fairProducerPK10M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairProducerPK10M100000[3],
      ready_fairProducerPK10M100000[4],
      title = "M = 100000",
      label = "fair PK 10",
      size = ddpi,
      w = 2)

ready_fairProducerPK100M100000 = by(sort(CSV.read("fairProducerPK100M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairProducerPK100M100000[3],
      ready_fairProducerPK100M100000[4],
      title = "M = 100000",
      label = "fair PK 100",
      size = ddpi,
      w = 2)

ready_fairProducerPK1000M100000 = by(sort(CSV.read("fairProducerPK1000M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairProducerPK1000M100000[3],
      ready_fairProducerPK1000M100000[4],
      title = "M = 100000",
      label = "fair PK 1000",
      size = ddpi,
      w = 2)

#fair - small value more possible
ready_fairSVProducerPK10M100000 = by(sort(CSV.read("fairSVProducerPK10M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVProducerPK10M100000[3],
      ready_fairSVProducerPK10M100000[4],
      title = "M = 100000",
      label = "fair SV PK 10",
      size = ddpi,
      w = 2)

ready_fairSVProducerPK100M100000 = by(sort(CSV.read("fairSVProducerPK100M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

plot!(ready_fairSVProducerPK100M100000[3],
      ready_fairSVProducerPK100M100000[4],
      title = "M = 100000",
      label = "fair SV PK 100",
      size = ddpi,
      w = 2)

ready_fairSVProducerPK1000M100000 = by(sort(CSV.read("fairSVProducerPK1000M100000.csv"), 3), [1,2,3]) do df
    DataFrame(avg_time = mean(df[4]))
end

producerM100000 = plot!(ready_fairSVProducerPK1000M100000[3],
      ready_fairSVProducerPK1000M100000[4],
      title = "Producer - M = 100000",
      label = "fair SV PK 1000",
      size = ddpi,
      ylabel = "Time [ns]",
      xlabel = "Buffer size",
      legend = :topleft,
      w = 2)

print()

# %%
consumerM1000

# %%
consumerM10000

# %%
consumerM100000

# %%
producerM1000

# %%
producerM10000

# %%
producerM100000
